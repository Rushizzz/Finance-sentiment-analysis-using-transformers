# %%
from datasets import load_dataset

# %%
data = load_dataset('financial_phrasebank', 'sentences_50agree')

# %%
df = data['train']

# %%
x = df['sentence']
y = df['label']

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification

model_name = "mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
classifier = pipeline("sentiment-analysis",model=model, tokenizer= tokenizer)
# Out:
# config.json:   0%|          | 0.00/933 [00:00<?, ?B/s]
# C:\Users\rushi\.conda\envs\Finance\Lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\rushi\.cache\huggingface\hub\models--mrm8488--distilroberta-finetuned-financial-news-sentiment-analysis. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
def tempo(val):
    print(x_train[val])
    dict = {
        0: 'negative',
        1: 'neutral',
        2: 'positive'
    }
    result = dict[y_train[val]]
    print(result)
    print(classifier.predict(x_train[val]))

# %%
import requests

url = ('https://newsapi.org/v2/top-headlines?sources=google-news-in&category=business&apiKey=cef60813d9da4655ae7fe2ef2446060a')

url3 = ('https://newsapi.org/v2/top-headlines?country=in&category=business&apiKey=cef60813d9da4655ae7fe2ef2446060a')

def GetNewsOnEverything(query):
    url2 = (f'https://newsapi.org/v2/everything?q={query}&apiKey=cef60813d9da4655ae7fe2ef2446060a')
    response = requests.get(url2)
    dict = {}
    # print(response.json())
    dict = response.json()
    return dict

newsDict = GetNewsOnEverything("Infosys")

# %%
newsDict
# Out:
# {'status': 'ok',
#  'totalResults': 972,
#  'articles': [{'source': {'id': None, 'name': 'ReadWrite'},
#    'author': 'Graeme Hanna',
#    'title': 'Indian IT giants HCL, Infosys, TCS and Wipro prosper on demand for AI',
#    'description': 'Indian IT giants HCL, Infosys, TCS and Wipro reported strong financial results in their latest quarterly earnings, fueled largely by […]\nThe post Indian IT giants HCL, Infosys, TCS and Wipro prosper on demand for AI appeared first on ReadWrite.',
#    'url': 'https://readwrite.com/indias-big-four-services-giants-soar-on-demand-for-ai/',
#    'urlToImage': 'https://readwrite.com/wp-content/uploads/india.jpg',
#    'publishedAt': '2024-01-18T14:03:14Z',
#    'content': 'Indian IT giants HCL, Infosys, TCS and Wipro reported strong financial results in their latest quarterly earnings, fueled largely by rising demand for artificial intelligence (AI) technology.\r\nThough… [+1778 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Tomi Kilgore',
#    'title': 'Wipro’s stock having best day in 16 years amid signs IT consulting has bottomed',
#    'description': 'Fellow India-based IT consultant Infosys’ stock surges again, after breaking a string of disappointing earnings reports.',
#    'url': 'https://www.marketwatch.com/story/wipros-stock-having-best-day-in-16-years-amid-signs-it-consulting-has-bottomed-590e1643',
#    'urlToImage': 'https://images.mktw.net/im-09168121/social',
#    'publishedAt': '2024-01-12T18:12:00Z',
#    'content': 'Shares of Wipro Ltd. rocketed Friday, after the India-based information-technology consultant beat fiscal third-quarter profit expectations, to snap a streak of earning misses amid a jump in large de… [+2343 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Tomi Kilgore',
#    'title': 'Infosys’s stock bounces after analyst’s buy call, as IT spending bottoms out',
#    'description': "Infosys' U.S.-listed stock rose Thursday after J.P. Morgan turned bullish, saying the India-based information-technology services company should benefit as discretionary tech spending bottoms out in the coming months.",
#    'url': 'https://www.marketwatch.com/story/infosyss-stock-bounces-after-analysts-buy-call-as-it-spending-bottoms-out-6285687b',
#    'urlToImage': 'https://images.mktw.net/im-63498407/social',
#    'publishedAt': '2024-01-04T14:18:00Z',
#    'content': 'U.S.-listed shares of Infosys Ltd. were headed for their first gain of 2024 on Thursday, after J.P. Morgan turned bullish, saying the India-based information-technology services company should benefi… [+2309 chars]'},
#   {'source': {'id': None, 'name': 'Theregister.com'},
#    'author': 'Simon Sharwood',
#    'title': 'Working from home never looked better: leopard stalks around Infosys and TCS campuses',
#    'description': 'No consultants were mauled or eaten but some were quite scared\nIndian forestry authorities have laid traps for a leopard that was spotted prowling near campuses used by tech services giants Infosys and TCS.…',
#    'url': 'https://www.theregister.com/2024/01/17/leopard_infosys_tcs_india/',
#    'urlToImage': 'https://regmedia.co.uk/2024/01/17/leonardo_ai_leopard_using_computer.jpg',
#    'publishedAt': '2024-01-17T04:29:13Z',
#    'content': 'Indian forestry authorities have laid traps for a leopard that was spotted prowling near campuses used by tech services giants Infosys and TCS.\r\nThe beast was spotted yesterday in the Indore Super Co… [+1726 chars]'},
#   {'source': {'id': None, 'name': 'Theregister.com'},
#    'author': 'Laura Dobberstein',
#    'title': "India's big four services giants soar on demand for AI",
#    'description': 'Pipelines are full, but hiring has slowed\nIndian IT service outfit HCL’s share price hit a record high this week, and scrip for its peers Infosys, TCS and Wipro also spiked, after the four announced quarterly results that revealed strong deal pipeline fueled …',
#    'url': 'https://www.theregister.com/2024/01/18/hcl_infosys_tcs_wipro_results/',
#    'urlToImage': 'https://regmedia.co.uk/2024/01/18/shutterstock_india_growth.jpg',
#    'publishedAt': '2024-01-18T06:34:11Z',
#    'content': 'Indian IT service outfit HCLs share price hit a record high this week, and scrip for its peers Infosys, TCS and Wipro also spiked, after the four announced quarterly results that revealed strong deal… [+4420 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': None,
#    'title': 'TCS, Infosys Show Dismal Growth as Clients Remain Cautious',
#    'description': None,
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_930c15c5-6605-40f5-9863-84dac38fbc4c',
#    'urlToImage': None,
#    'publishedAt': '2024-01-11T11:47:34Z',
#    'content': 'Si vous cliquez sur «\xa0Tout accepter\xa0», nos partenaires (y compris 244 qui font partie du Cadre de transparence et de consentement dIAB) et nous utiliserons également des témoins et vos données person… [+982 chars]'},
#   {'source': {'id': None, 'name': 'Theregister.com'},
#    'author': 'Laura Dobberstein',
#    'title': '‘Technical glitch’ in payroll software sparks riots in Papua New Guinea',
#    'description': 'PLUS: Microsoft taps 700 million new customers in China; AI comes to Korean DMZ; India’s semiconductor sector surges\nAsia in Brief Papua New Guinea (PNG) has implemented a two-week state of emergency after failure to reconfigure the nation’s payroll system fo…',
#    'url': 'https://www.theregister.com/2024/01/14/asia_tech_news_roundup/',
#    'urlToImage': 'https://regmedia.co.uk/2022/02/17/shutterstock_asia_pacific.jpg',
#    'publishedAt': '2024-01-14T23:05:06Z',
#    'content': 'Asia in Brief Papua New Guinea (PNG) has implemented a two-week state of emergency after failure to reconfigure the nations payroll system for government employees sparked riots that resulted in mult… [+5469 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Matt Turner',
#    'title': 'What the global elite are saying about AI behind closed doors',
#    'description': 'The AI era at Davos 2024: Copilots, task automation, workforce reskilling, and human augmentation.',
#    'url': 'https://www.businessinsider.com/davos-global-elite-saying-about-ai-behind-closed-doors-2024-1',
#    'urlToImage': 'https://i.insider.com/65aae75ddcdb354a9859507e?width=1200&format=jpeg',
#    'publishedAt': '2024-01-19T22:15:21Z',
#    'content': 'OpenAI CEO Sam Altman at the World Economic Forum in Davos, Switzerland.FABRICE COFFRINI/Getty Images\r\n<ul><li>Business Insider editor in chief Matt Turner attended the World Economic Forum.\xa0</li><li… [+7679 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'ETMarkets.com',
#    'title': 'Hot Stocks: UBS upgrades Infosys & downgrades Wipro; JPMorgan upgrades TCS',
#    'description': 'TCS has a neutral rating, but UBS raised the target price to Rs 4,050 from Rs 3,700 earlier. HCL Technologies has a neutral rating, but the target price was raised to Rs 1,540 from Rs 1,350 earlier.',
#    'url': 'https://economictimes.indiatimes.com/markets/options/hot-stocks-ubs-upgrades-infosys-downgrades-wipro-jpmorgan-upgrades-tcs/articleshow/106532187.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-106532179,width-1200,height-630,imgsize-74210,overlay-etmarkets/photo.jpg',
#    'publishedAt': '2024-01-04T04:24:55Z',
#    'content': 'Brokerage firm UBS upgraded Infosys and downgraded Wipro ahead of the December quarter results. JPMorgan upgraded TCS, Infosys as well as HCL Technologies. JPMorgan upgraded Tata Motors to overweight… [+2384 chars]'},
#   {'source': {'id': None, 'name': 'The Indian Express'},
#    'author': 'PTI',
#    'title': 'Infosys net profit declines 7.3% to Rs 6,106 crore in Q3',
#    'description': 'The acquisition of InSemi is expected to close during the fourth quarter of FY24, subject to customary closing conditions, the\xa0filing\xa0said.',
#    'url': 'https://indianexpress.com/article/business/companies/infosys-net-profit-declines-7-3-to-rs-6106-crore-in-q3-9105336/',
#    'urlToImage': 'https://images.indianexpress.com/2024/01/Infosys-q3-net-profit.jpg',
#    'publishedAt': '2024-01-11T11:50:48Z',
#    'content': 'IT company Infosys on Thursday posted a 7.3 per cent decline in consolidated net profit at Rs 6,106 crore in the third quarter of the current financial year.\r\nThe company had posted a net profit (att… [+725 chars]'},
#   {'source': {'id': 'techradar', 'name': 'TechRadar'},
#    'author': 'Craig Hale',
#    'title': 'Young people have "enormous responsibility to work very, very hard" - tech titan doubles down on his call for employees to work punishingly long hours',
#    'description': 'Infosys co-founder Narayana Murthy asks workers to be extremely productive, says he worked up to 90 hours/week.',
#    'url': 'https://www.techradar.com/pro/tech-titan-doubles-down-on-his-call-for-employees-to-work-punishingly-long-hours',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/StT4DpZ3N8oNQnm5DZWja3-1200-80.jpg',
#    'publishedAt': '2024-01-15T14:02:15Z',
#    'content': 'Indian billionaire and Infosys co-founder Narayana Murthy has reiterated his call for the country’s youth to embrace long working hours as a means of contributing to the country’s progress and helpin… [+1970 chars]'},
#   {'source': {'id': None, 'name': 'Xataka.com'},
#    'author': 'Rubén Andrés',
#    'title': 'Cuándo y cómo se va a implementar la jornada de 38,5 horas, la gran reforma laboral del Gobierno para 2024',
#    'description': 'Uno de los puntos más polémicos del pacto de investidura entre Sumar y PSOE, fue el que daba continuidad a la reducción de la jornada laboral semanal que ya se estaba llevando a cabo durante la anterior legislatura y que, de hecho, ambas fuerzas políticas lle…',
#    'url': 'https://www.xataka.com/empresas-y-economia/cuando-como-se-va-a-implementar-jornada-38-5-horas-gran-reforma-laboral-gobierno-para-2024',
#    'urlToImage': 'https://i.blogs.es/71aadd/pexels-yury-kim-585418/840_560.jpeg',
#    'publishedAt': '2024-01-03T15:00:02Z',
#    'content': 'Uno de los puntos más polémicos del pacto de investidura entre Sumar y PSOE, fue el que daba continuidad a la reducción de la jornada laboral semanal que ya se estaba llevando a cabo durante la anter… [+4482 chars]'},
#   {'source': {'id': None, 'name': 'The Indian Express'},
#    'author': 'ENS Economic Bureau',
#    'title': 'Day after Budget: Sensex jumps 1,444 points intra-day, pares gains',
#    'description': 'Information technology, power and metal stocks led the bull rally on heavy buying. Shares of Reliance Industries 2.18 per cent and Infosys gained 2.26 per cent. The Sensex had fallen by 107 points on Thursday.',
#    'url': 'https://indianexpress.com/article/business/market/day-after-budget-sensex-jumps-1444-points-intra-day-pares-gains-9141528/',
#    'urlToImage': 'https://images.indianexpress.com/2024/02/bse-bombay-stock-exchange-bloomberg-1200-1.jpg',
#    'publishedAt': '2024-02-02T21:55:54Z',
#    'content': 'A day after the Finance Minister presented a conservative and non-populist interim Budget, domestic stock markets staged a rally with the benchmark Sensex soaring by 1444 points to cross the 73,000 m… [+2865 chars]'},
#   {'source': {'id': None, 'name': 'Computerworld'},
#    'author': 'Sascha Brodsky',
#    'title': 'Infosys to acquire InSemi',
#    'description': "Infosys on Thursday announced plans to acquire InSemi, a company specializing in semiconductor design and embedded services, for an undisclosed sum.\r\nThe acquisition, set to be finalized in the current quarter, aims to enhance Infosys' engineering R&D experti…",
#    'url': 'https://www.computerworld.com/article/3712132/infosys-to-acquire-insemi.html',
#    'urlToImage': 'https://images.idgesg.net/images/article/2023/02/shutterstock-deal-merger-acquisition-100937367-large.jpg?auto=webp&quality=85,70',
#    'publishedAt': '2024-01-12T21:25:00Z',
#    'content': 'Infosys on Thursday announced plans to acquire InSemi, a company specializing in semiconductor design and embedded services, for an undisclosed sum.\r\nThe acquisition, set to be finalized in the curre… [+2256 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Ranjit Shinde',
#    'title': 'By deal count, IT companies may perform better',
#    'description': "In addition, HCLTech's operating margin (EBIT margin) expanded significantly by 130 basis points sequentially to 19.8%. This compares with the contraction reported by Infosys and Wipro and an expansion in TCS margin after excluding one-off items.",
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/earnings/by-deal-count-it-companies-may-perform-better/articleshow/106795419.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-106795461,width-1200,height-630,imgsize-50694,overlay-etmarkets/photo.jpg',
#    'publishedAt': '2024-01-13T01:58:42Z',
#    'content': 'ET Intelligence Group: HCL Technologies (HCLTech) on Friday delivered better-than-expected numbers for the December quarter helped by the ramp up in Verizon deal and buoyancy in the software licence … [+2846 chars]'},
#   {'source': {'id': None, 'name': 'The Indian Express'},
#    'author': 'ENS Economic Bureau',
#    'title': 'Sensex hits a new high of 72,568, Nifty surges 247 points',
#    'description': 'A 19 per cent surge in the country’s net direct tax collection also supported domestic equities to make new highs on Friday, said Siddhartha Khemka, Head - Retail Research, Motilal Oswal Financial Services Ltd',
#    'url': 'https://indianexpress.com/article/business/market/sensex-nifty-high-9107060/',
#    'urlToImage': 'https://images.indianexpress.com/2024/01/sensex-2.jpg',
#    'publishedAt': '2024-01-12T13:55:43Z',
#    'content': 'Domestic equity benchmarks Sensex and Nifty touched record highs on Friday on account of buying in information technology (IT) stocks, including Tata Consultancy Services (TCS) and Infosys Ltd.The BS… [+2764 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'ET Bureau',
#    'title': 'Nifty expected to face selling pressure, support at 21,250: Analysts',
#    'description': 'However, if the index surpasses and maintains levels above 21,500, analysts anticipate index to move to 21,600-21,700 range. SBI, NMDC, SAIL, RIL, Infosys, GAIL, Siemens, Tata Power, Coforge, MGL, Star Cement, and LIC Housing have formed bullish patterns on c…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/nifty-expected-to-face-selling-pressure-support-at-21250-analysts/articleshow/107213091.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-107213088,width-1200,height-630,imgsize-26662,overlay-etmarkets/photo.jpg',
#    'publishedAt': '2024-01-29T00:20:11Z',
#    'content': 'Most technical indicators suggest a correction in the near term. If Nifty falls below 21,250, it is likely to move towards the 21,000-20,900 range. However, if the index surpasses and maintains level… [+3612 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Christine Idzelis, Tomi Kilgore',
#    'title': 'India is winning over investors as Chinese stocks struggle, these charts show',
#    'description': 'India is capturing investors’ attention, as exchange-traded funds targeting stocks in the emerging market extend their climb in 2024.',
#    'url': 'https://www.marketwatch.com/story/india-is-winning-over-investors-as-chinese-stocks-struggle-these-charts-show-b2ad213f',
#    'urlToImage': 'https://images.mktw.net/im-94422071/social',
#    'publishedAt': '2024-02-01T16:04:00Z',
#    'content': 'India is capturing investors attention, as exchange-traded funds targeting stocks in the emerging market extend their climb in 2024.The countrys economy, which stands to benefit from a changing globa… [+5289 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'ETMarkets.com',
#    'title': 'F&O stocks to buy or sell today: MCX, IOC among top 7 trading ideas',
#    'description': 'Positive setup was seen in Infosys, OFSS, Coforge, ONGC, Birla Soft, HCL Tech, Persistent Systems, TCS, PNB, Tata Consumer, LTTS, Canara Bank, L&T, IOC, Bharti Airtel, Trent and IndusInd Bank. On the weekly options front, the maximum Call OI is placed at 2250…',
#    'url': 'https://economictimes.indiatimes.com/markets/options/fo-stocks-to-buy-or-sell-today-mcx-ioc-among-top-7-trading-ideas-for-15-january-2024/articleshow/106852481.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-106852467,width-1200,height-630,imgsize-88940,overlay-etmarkets/photo.jpg',
#    'publishedAt': '2024-01-15T04:35:56Z',
#    'content': 'The Indian market is likely to trade higher on Monday tracking positive global cues.The Nifty future closed positive with gains of 1.24% at 21947 levels on Friday. India VIX was up by 2.58% from 12.7… [+2073 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Andrew Duncan, Forbes Councils Member, \n Andrew Duncan, Forbes Councils Member\n https://www.forbes.com/sites/forbestechcouncil/people/andrewduncan/',
#    'title': 'What Every Leadership Team Needs To Know About Generative AI',
#    'description': 'The fact remains that most leaders want to know when to act—and how. Here are three questions executive leadership teams should ask before embracing generative AI.',
#    'url': 'https://www.forbes.com/sites/forbestechcouncil/2024/01/19/what-every-leadership-team-needs-to-know-about-generative-ai/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/64c93f94b69a0cb9cd69db67/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#    'publishedAt': '2024-01-19T13:45:00Z',
#    'content': 'Andrew Duncan, CEO and Managing Partner, Infosys Consulting.\r\ngetty\r\nGenerative AI is at a tipping point in technology adoption. Its predicted to become a $1.3 trillion market by 2032, and its set to… [+5133 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Steve Goldstein, Barbara Kollmeyer',
#    'title': 'Wall Street firms getting excited over Japan as Nikkei keeps hitting records',
#    'description': 'JPMorgan and Bank of America are both pointing to wage growth as a reason to buy Japanese stocks.',
#    'url': 'https://www.marketwatch.com/story/wall-street-firms-getting-excited-over-japan-as-nikkei-keeps-hitting-records-f2d6119b',
#    'urlToImage': 'https://images.mktw.net/im-95137655/social',
#    'publishedAt': '2024-01-11T11:50:00Z',
#    'content': 'Japanese stocks were back in the spotlight from top Wall Street firms, as the benchmark Nikkei 225 crossed the 35,000 mark for the first time in nearly 34 years.The Nikkei 225 \r\n JP:NIK\r\n ended up 1.… [+6227 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Broker Research',
#    'title': 'Buy Infosys; target of Rs 1824: Geojit',
#    'description': 'Geojit is bullish on Infosys has recommended buy rating on the stock with a target price of Rs 1824 in its research report dated January 17, 2024.',
#    'url': 'https://www.moneycontrol.com/news/business/stocks/buy-infosys-target-of-rs-1824-geojit-12080401.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2024/01/Buy_1280x720_3-770x433.png',
#    'publishedAt': '2024-01-19T04:46:19Z',
#    'content': "Geojit's research report on Infosys\r\nInfosys Ltd provides information technology (IT) consulting and software services, including e-business, programme management and supply chain solutions. It also … [+1224 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': None,
#    'title': 'Infosys Limited (NYSE:INFY) Q3 2024 Earnings Call Transcript',
#    'description': None,
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_2ee4dcd6-fa0d-40a1-aed8-718e2cda9541',
#    'urlToImage': None,
#    'publishedAt': '2024-01-12T13:17:42Z',
#    'content': 'Si vous cliquez sur «\xa0Tout accepter\xa0», nos partenaires (y compris 244 qui font partie du Cadre de transparence et de consentement dIAB) et nous utiliserons également des témoins et vos données person… [+982 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': None,
#    'title': "India's TCS, Infosys see revenue dips on client spending cuts",
#    'description': None,
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_1dc4691c-d2b0-473e-8445-dc445be00def',
#    'urlToImage': None,
#    'publishedAt': '2024-01-11T14:39:27Z',
#    'content': 'Si vous cliquez sur «\xa0Tout accepter\xa0», nos partenaires (y compris 244 qui font partie du Cadre de transparence et de consentement dIAB) et nous utiliserons également des témoins et vos données person… [+982 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Broker Research',
#    'title': 'Buy Infosys; target of Rs 1850: Emkay Global Financial',
#    'description': 'Emkay Global Financial is bullish on Infosys has recommended buy rating on the stock with a target price of Rs 1850 in its research report dated January 12, 2024.',
#    'url': 'https://www.moneycontrol.com/news/business/buy-infosys-target-of-rs-1850-emkay-global-financial-12040691.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2024/01/Buy-378x213.png',
#    'publishedAt': '2024-01-12T07:34:36Z',
#    'content': "Emkay Global Financial's research report on Infosys\r\nInfosys reported a tad better-than-expected operating performance for Q3. Revenue declined 1.2% QoQ to USD4.66bn (1% in cc) due to weak discretion… [+1337 chars]"},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Sunil Shankar Matkar',
#    'title': 'Trade setup for Thursday: 15 things to know before opening bell',
#    'description': 'A short build-up was seen in 53 stocks including National Aluminium Company, LTIMindtree, Escorts Kubota, Infosys and Coforge',
#    'url': 'https://www.moneycontrol.com/news/business/markets/trade-setup-for-thursday-15-things-to-know-before-opening-bell-15-11994851.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2023/10/Nifty_sensex-6-770x433.jpg',
#    'publishedAt': '2024-01-03T16:54:30Z',
#    'content': 'With the consistent correction and the formation of lower highs and lower lows for yet another session, the 21,500 on the Nifty50 may be a make-or-break level in the coming sessions. If the index fal… [+8873 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Teena Virmani',
#    'title': 'Buy Infosys; target of Rs 1870: YES Securities',
#    'description': 'YES Securities is bullish on Infosys has recommended buy rating on the stock with a target price of Rs 1870 in its research report dated January 12, 2024.',
#    'url': 'https://www.moneycontrol.com/news/business/stocks/buy-infosys-target-of-rs-1870-yes-securities-12039751.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2024/01/Buy_1280x720_3-770x433.png',
#    'publishedAt': '2024-01-12T06:00:36Z',
#    'content': "YES Securities' research report on Infosys\r\nInfosys (INFO) reported broadly inline performance for the quarter. The revenue growth was above estimates; while EBIT margin was inline with expectation. … [+1399 chars]"},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Vaibhavi Ranjan',
#    'title': 'Infosys soars 6% after analysts say worst behind as Q3 deal wins rekindle hope',
#    'description': 'While Infosys#39; net missed the Street#39;s estimate, its revenue was a tad above expectations. Net new deal wins also remained strong, which makes analysts hopeful of a recovery in the coming quarters',
#    'url': 'https://www.moneycontrol.com/news/business/markets/infosys-q3-analysts-say-worst-behind-as-deal-wins-rekindle-hope-12038391.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2021/10/Infosys-770x433.jpg',
#    'publishedAt': '2024-01-12T03:33:42Z',
#    'content': "Shares of India's second largest IT services company Infosys surged nearly 6 percent in opening trade on January 12 after brokerages expect the worst for the company to be behind on the back of its s… [+3035 chars]"},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Moneycontrol News',
#    'title': 'Spending on Gen AI in Asia-Pacific region to triple to $3.4 bn in 2024, saysÂ\xa0Infosys Research',
#    'description': 'China leads the region, with investment expected to grow by more than 160% to $2.1 billion, shows the finding from the research arm of Infosys.',
#    'url': 'https://www.moneycontrol.com/news/technology/spending-on-gen-ai-in-asia-pacific-region-to-triple-to-3-4-bn-in-2024-says-infosys-research-12133011.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2023/05/Infosys.jpg',
#    'publishedAt': '2024-01-27T07:28:28Z',
#    'content': 'Companies across Asia-Pacific region will\xa0nearly triple their investments in generative artificial intelligence (Gen AI) to $3.4 billion in 2024, according to a new research from the Infosys Knowledg… [+1403 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Abhishek Shingare',
#    'title': 'Infosys Standalone December 2023 Net Sales at Rs 32,491.00 crore, up 0.31% Y-o-Y',
#    'description': 'NULL',
#    'url': 'https://www.moneycontrol.com/news/business/earnings/infosys-standalone-december-2023-net-sales-at-rs-32491-00-crore-up-0-31-y-o-y-12076751.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2017/04/shutterstock_310523045-462x435.jpg',
#    'publishedAt': '2024-01-18T08:14:04Z',
#    'content': 'Reported Standalone quarterly numbers for Infosys are:Net Sales at Rs 32,491.00 crore in December 2023 up 0.31% from Rs. 32,389.00 crore in December 2022.\r\nQuarterly Net Profit at Rs. 6,552.00 crore … [+409 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'M F Saudamani',
#    'title': 'Short Call | Sector rotation boosts realty; PVR flops, Bajaj Financeâ\x80\x99s bumper Q3, Sobha in focus',
#    'description': 'The focus now shifts to the IT services sector as heavyweights Infosys and TCS get ready to unveil their quarterly numbers',
#    'url': 'https://www.moneycontrol.com/news/business/markets/short-call-sector-rotation-boosts-realty-pvr-flops-bajaj-finances-bumper-q3-sobha-in-focus-12001451.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2023/12/markets17.jpg',
#    'publishedAt': '2024-01-05T01:36:30Z',
#    'content': 'Buy only what you understand, believe in, and intend to stick with - even when others are chasing the next miracle. - Peter Lynch\r\nBuy-on-dips continues to work like a charm. On Thursday, realty was … [+3214 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'ET Bureau',
#    'title': 'Nifty on a strong base, to maintain bullish trend: Analysts',
#    'description': '\u200bAfter reaching a lifetime high at 22,124, the Nifty experienced a dip and found support at 21,350-21,400, which aligned with the 26-day exponential moving average, thereby establishing this as a crucial support.',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/nifty-on-a-strong-base-to-maintain-bullish-trend-analysts/articleshow/107064299.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-107064304,width-1200,height-630,imgsize-79540,overlay-etmarkets/photo.jpg',
#    'publishedAt': '2024-01-23T00:20:55Z',
#    'content': 'Technical charts suggest a sideways-to-positive outlook from a broader market perspective. The Nifty has established a strong base around 21,450 levels, and a sustained position above this level is l… [+3757 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Sucheta Anchaliya',
#    'title': 'FO Buzzers: TCS may head for all-time high, Infosys support base shifts up; watch these levels to buy on dips',
#    'description': 'Post today#39;s gains analysts predict that TCS may head to all-time high levels of around Rs 4000. Infosys on other hand may challenge resistance of Rs 1660.',
#    'url': 'https://www.moneycontrol.com/news/business/earnings/f-watch-these-levels-to-buy-on-dips-12041071.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2024/01/INFOSYS-Q3-TT-770x433.jpg',
#    'publishedAt': '2024-01-12T08:28:14Z',
#    'content': 'Index heavyweights TCS and Infosys Q3 results propelled the Nifty IT index by 5\xa0percent, pulling NSE Nifty 50 to a new record high. Nifty 50 was holding near 21,850 in the afternoon trade on January … [+2548 chars]'},
#   {'source': {'id': None, 'name': 'Raspberrypi.org'},
#    'author': 'Philip Colligan',
#    'title': 'Code Club at Number Ten Downing Street',
#    'description': 'With the rapid advances in digital technologies like artificial intelligence, it’s more important than ever that every young person has the opportunity to learn how computers are being used to change the world and to develop the skills and confidence to get c…',
#    'url': 'https://www.raspberrypi.org/blog/code-club-number-ten-downing-street/',
#    'urlToImage': 'https://www.raspberrypi.org/app/uploads/2024/01/5H1A4377-500x334.jpg',
#    'publishedAt': '2024-01-25T14:09:33Z',
#    'content': 'With the rapid advances in digital technologies like artificial intelligence, it’s more important than ever that every young person has the opportunity to learn how computers are being used to change… [+3277 chars]'},
#   {'source': {'id': None, 'name': 'Startupi.com.br'},
#    'author': 'Bruna Galati',
#    'title': 'Infosys faz aquisição da InSemi, empresa indiana de design de semicondutores',
#    'description': 'Startupi\n\nInfosys faz aquisição da InSemi, empresa indiana de design de semicondutores\nInfosys faz aquisição da InSemi, empresa de design de semicondutores \nO post Infosys faz aquisição da InSemi, empresa indiana de design de semicondutores aparece primeiro e…',
#    'url': 'https://startupi.com.br/infosys-faz-aquisicao-da-insemi/',
#    'urlToImage': 'https://startupi.com.br/wp-content/uploads/2024/01/Insemi.jpeg',
#    'publishedAt': '2024-01-11T17:07:26Z',
#    'content': 'A Infosys, de consultoria e serviços digitais, fez um acordo definitivo para adquirir a InSemi, empresa indiana de design de semicondutores e serviços incorporados. Este investimento estratégico fort… [+2895 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': None,
#    'title': 'Indian IT stocks rally on TCS, Infosys better-than-feared results',
#    'description': None,
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_c41d845a-8013-41f8-9110-bd488369c5b3',
#    'urlToImage': None,
#    'publishedAt': '2024-01-12T03:51:18Z',
#    'content': 'Si vous cliquez sur «\xa0Tout accepter\xa0», nos partenaires (y compris 244 qui font partie du Cadre de transparence et de consentement dIAB) et nous utiliserons également des témoins et vos données person… [+982 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Vaibhavi Ranjan',
#    'title': 'Nifty scales fresh record high, Sensex up 680 points as Q3 IT earnings lift mood',
#    'description': 'Information technology stocks, which soared 3-7 percent, were the biggest reason for Nifty#39;s gain of 190 points. The Nifty IT index was the top sectoral gainer as it zoomed 4.75 percent',
#    'url': 'https://www.moneycontrol.com/news/business/markets/nifty-scales-fresh-record-high-sensex-up-680-points-as-q3-it-earnings-lift-mood-12039391.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2024/01/Stock-Market-1-2-770x433.jpg',
#    'publishedAt': '2024-01-12T05:49:23Z',
#    'content': 'The benchmark Nifty extended its early gains and scaled a record high of 21837.85 points on January 12, while the Sensex was 160\xa0points shy of its new peak.\r\nThe strong run was driven by information … [+1961 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Moneycontrol News',
#    'title': 'Infosys headcount shrinks by 6,101 in Q3, fourth consecutive quarter of decline',
#    'description': 'The company ended the December quarter with 322,663 employees',
#    'url': 'https://www.moneycontrol.com/news/technology/infosys-headcount-shrinks-by-6101-in-q3-fourth-consecutive-quarter-of-decline-12034151.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2023/12/Infosys-770x433.jpg',
#    'publishedAt': '2024-01-11T12:11:52Z',
#    'content': 'Bengaluru-based IT services major Infosys saw its headcount shrink by\xa06,101 for the quarter ending December 31, making\xa0it the fourth consecutive quarter in which the company ended with fewer employee… [+971 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Moneycontrol News',
#    'title': 'IT stocks gain on interest rate optimism; Infosys, TCS, Wipro up 1% each',
#    'description': 'Analysts expect a muted quarter for the IT industry but there is optimism in the sector in anticipation of the end of the rate-tightening cycle',
#    'url': 'https://www.moneycontrol.com/news/business/markets/it-stocks-gain-on-interest-rate-optimism-infosys-tcs-wipro-up-1-each-12003061.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2023/08/software2-770x433.jpg',
#    'publishedAt': '2024-01-05T07:36:57Z',
#    'content': 'IT stocks gained on January 5, with TCS, Infosys and other big names rising more than a percent each as optimism prevailed over the end of interest-rate hike cycle despite near-term concerns over the… [+2732 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Navisha Joshi',
#    'title': 'Buzzing Stocks: Reliance Home Finance, MM, Infosys, TCS, Nykaa, Tata Power, LIC and others in news',
#    'description': 'Stocks to watch: Check out the companies making headlines before the opening bell today, on January 12, 2024.',
#    'url': 'https://www.moneycontrol.com/news/photos/business/stocks/buzzing-stocks-reliance-home-finance-mm-infosys-tcs-nykaa-concorp-tata-power-lic-and-others-in-news-12037731.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2024/01/Nifty_sensex_marketup-1-770x433.jpg',
#    'publishedAt': '2024-01-12T01:28:46Z',
#    'content': 'Reliance Home Finance: Prashant Utreja has ceased to be the Chief Executive Officer and key managerial personnel of the company as he resigned with effect from January 11.\r\nMahindra and Mahindra: Mah… [+6253 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Rakesh Patil',
#    'title': 'Taking Stock: Market ends with minor gains amid volatility; small, midcaps shine',
#    'description': 'Hero MotoCorp, Bajaj Auto, Reliance Industries, Axis Bank and BPCL were among the top Nifty gainers, while losers included Infosys, Dr Reddy#39;s Laboratories, SBI Life Insurance, HUL and Wipro',
#    'url': 'https://www.moneycontrol.com/news/business/markets/taking-stock-market-ends-with-minor-gains-amid-volatility-small-midcaps-shine-12035101.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2024/01/bse_nse_stockmarket_nifty_sensex-3-770x433.jpg',
#    'publishedAt': '2024-01-11T10:16:55Z',
#    'content': 'The equity benchmarks eked out marginal gains in yet another day of choppy trade, with investor turning cautious ahead of the December quarter earnings and US inflation data.\r\nAt close, the Sensex wa… [+3485 chars]'},
#   {'source': {'id': None, 'name': 'International Business Times'},
#    'author': 'AFP News',
#    'title': "India's TCS, Infosys See Revenue Dips On Client Spending Cuts",
#    'description': 'Indian IT giants TCS and Infosys both signalled weak revenue growth in quarterly results Thursday as a client spending slowdown deepened a seasonally weak time for the sector.',
#    'url': 'https://www.ibtimes.com/indias-tcs-infosys-see-revenue-dips-client-spending-cuts-3721882',
#    'urlToImage': 'https://d.ibtimes.com/en/full/4505816/infosys-headed-salil-parekh-it-rival-tcs-earn-more-80-percent-their-revenues-western-markets.jpg',
#    'publishedAt': '2024-01-11T14:42:22Z',
#    'content': 'Indian IT giants TCS and Infosys both signalled weak revenue growth in quarterly results Thursday as a client spending slowdown deepened a seasonally weak time for the sector.\r\nBoth companies, the se… [+2455 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Omkar Patil',
#    'title': 'Hot Stocks: Bet on Infosys, JSW Energy, GAIL India for the short term',
#    'description': 'The immediate trading range for the Nifty 50 is anticipated to be between 21,500 and 21,800.',
#    'url': 'https://www.moneycontrol.com/news/business/markets/hot-stocks-bet-on-infosys-jsw-energy-gail-india-for-the-short-term-12089521.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2023/12/stocks_sensex_nifty_stockmarket5-770x433.jpg',
#    'publishedAt': '2024-01-20T00:18:47Z',
#    'content': 'The Nifty 50 concluded the session on a positive note at 21,622, managing to reclaim the 21-day EMA (exponential moving average) of 21,551. Despite forming a small Doji candle, the ability to stay ab… [+3095 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Sucheta Anchaliya',
#    'title': 'Selling pressure in IT stocks ahead of Infy, TCS results; hereâ\x80\x99s how traders position the market',
#    'description': 'The Nifty IT index is grappling to overcome the selling pressure emerging around the 36,000 mark. This hurdle must be surpassed to enter the next leg of upside, as per experts.',
#    'url': 'https://www.moneycontrol.com/news/business/earnings/selling-pressure-in-it-stocks-ahead-of-infy-tcs-results-heres-how-traders-position-the-market-12027841.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2021/09/software-770x433.jpg',
#    'publishedAt': '2024-01-10T09:50:57Z',
#    'content': 'With Tata Consultancy Services and Infosys set to kickstart Q3 FY2024 earnings on January 11, analysts note the persisting selling pressure in IT stocks at higher levels, and weakness in TCS, Infosys… [+3970 chars]'},
#   {'source': {'id': 'al-jazeera-english', 'name': 'Al Jazeera English'},
#    'author': 'Al Jazeera',
#    'title': 'Dominican Republic to trial four-day work week: Can it work globally?',
#    'description': "It's the first Caribbean country to trial such a move, amid a growing global call for such shifts.",
#    'url': 'https://www.aljazeera.com/news/2024/1/20/dominican-republic-to-trial-four-day-work-week-can-it-work-globally',
#    'urlToImage': 'https://www.aljazeera.com/wp-content/uploads/2024/01/AP17024580757056-1705569167.jpg?resize=1920%2C1440',
#    'publishedAt': '2024-01-20T11:44:23Z',
#    'content': 'In February, the Dominican Republic will become the first Caribbean nation to test a four-day work week, following similar trials in countries such as the United Kingdom.\r\nThe six-month pilot will be… [+5063 chars]'},
#   {'source': {'id': None, 'name': 'CNA'},
#    'author': None,
#    'title': 'Indian IT stocks rally on TCS, Infosys better-than-feared results',
#    'description': 'BENGALURU :Indian IT companies rallied more than 4 per cent on Friday after market leaders Tata Consultancy Services and Infosys posted better-than-feared quarterly reports, easing some concerns about a sector grappling with fears of sluggish demand.Shares of…',
#    'url': 'https://www.channelnewsasia.com/business/indian-it-stocks-rally-tcs-infosys-better-feared-results-4042831',
#    'urlToImage': 'https://onecms-res.cloudinary.com/image/upload/s--wQMZ_5lN--/fl_relative,g_south_east,l_one-cms:core:watermark:reuters,w_0.1/f_auto,q_auto/c_fill,g_auto,h_676,w_1200/v1/one-cms/core/2024-01-12t035118z_1_lynxmpek0b03k_rtroptp_3_infosys-results.jpg?itok=hWfkDYaT',
#    'publishedAt': '2024-01-12T03:51:18Z',
#    'content': 'BENGALURU :Indian IT companies rallied more than 4 per cent on Friday after market leaders Tata Consultancy Services and Infosys posted better-than-feared quarterly reports, easing some concerns abou… [+1254 chars]'},
#   {'source': {'id': None, 'name': 'DIE WELT'},
#    'author': 'Holger Zschäpitz, Anja Ettel',
#    'title': 'Erwartetes Wunder bei Paypal und der lukrative Walk-of-Fame-Index',
#    'description': 'In der heutigen Folge „Alles auf Aktien“ sprechen die Finanzjournalisten Anja Ettel und Holger Zschäpitz über eine Zocker-Idee für die Berichtssaison, eine Shortattacke auf Morphosys und was sonst noch wichtig wird in dieser Woche.',
#    'url': 'https://www.welt.de/podcasts/alles-auf-aktien/article249657854/Alles-auf-Aktien-Palantir-Amazon-Meta-So-lukrativ-ist-der-Walk-of-Fame-Index-aus-Davos.html',
#    'urlToImage': 'https://img.welt.de/img/podcasts/alles-auf-aktien/mobile244546290/3151353677-ci16x9-w1200/ettel-zschae-DWO-Podcast-Teaser-AllesAufAktien-mit-2zu3-ettel-zschaepitz-aw.jpg',
#    'publishedAt': '2024-01-22T04:03:18Z',
#    'content': 'Außerdem geht es um BASF, Netflix, Tesla, Intel, IBM, D.R. Horton, Teledyne, Valero Energy, Apple, Google, Microsoft, Amazon, McDonalds, Visa, Tencent, Mastercard, Coca Cola, Telekom, SAP, Mercedes B… [+770 chars]'},
#   {'source': {'id': None, 'name': 'CNA'},
#    'author': None,
#    'title': "India's TCS, Infosys jump on upbeat results, lift IT stocks",
#    'description': "BENGALURU : Shares of India's top IT services providers Tata Consultancy Services and Infosys rose between 3 per cent and 4.5 per cent on Friday after their results indicated a possible end to persisting sluggish demand.TCS, India's top IT exporter, and Infos…",
#    'url': 'https://www.channelnewsasia.com/business/indias-tcs-infosys-jump-upbeat-results-lift-it-stocks-4042831',
#    'urlToImage': 'https://onecms-res.cloudinary.com/image/upload/s--wQMZ_5lN--/fl_relative,g_south_east,l_one-cms:core:watermark:reuters,w_0.1/f_auto,q_auto/c_fill,g_auto,h_676,w_1200/v1/one-cms/core/2024-01-12t035118z_1_lynxmpek0b03k_rtroptp_3_infosys-results.jpg?itok=hWfkDYaT',
#    'publishedAt': '2024-01-12T03:51:18Z',
#    'content': "BENGALURU : Shares of India's top IT services providers Tata Consultancy Services and Infosys rose between 3 per cent and 4.5 per cent on Friday after their results indicated a possible end to persis… [+187 chars]"},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Sunil Shankar Matkar',
#    'title': 'Daily Voice | This fund manager believes IT could be a good pick with strong expectations of recovery',
#    'description': 'Sonam Srivastava says 2024 holds the potential for being a moderately positive year for the Indian equity markets.',
#    'url': 'https://www.moneycontrol.com/news/business/markets/daily-voice-this-fund-manager-believes-it-could-be-a-good-value-pick-now-with-strong-expectations-of-recovery-in-coming-quarters-12044701.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2021/11/Sonam_Srivastava1280-770x433.jpg',
#    'publishedAt': '2024-01-13T02:42:50Z',
#    'content': 'After IT biggies December 2023 quarter earnings, Sonam Srivastava of Wright Research, PMS, tells Moneycontrol that the cautious outlook expressed, particularly regarding macroeconomic uncertainties a… [+8619 chars]'},
#   {'source': {'id': None, 'name': 'CNA'},
#    'author': None,
#    'title': 'Infosys Q3 profit misses estimates on weak demand',
#    'description': "BENGALURU : Infosys, India's No.2 IT services provider, missed quarterly profit estimates on Thursday, hurt by weak demand from clients amid global economic uncertainty. Consolidated net profit fell 7.3 per cent to 61.06 billion rupees ($735.55 million) in th…",
#    'url': 'https://www.channelnewsasia.com/business/infosys-q3-profit-misses-estimates-weak-demand-4040671',
#    'urlToImage': 'https://onecms-res.cloudinary.com/image/upload/s--QVQhPo9Z--/fl_relative,g_south_east,l_one-cms:core:watermark:reuters,w_0.1/f_auto,q_auto/c_fill,g_auto,h_676,w_1200/v1/one-cms/core/2024-01-11t104817z_1_lynxmpek0a0e5_rtroptp_3_infosys-results.jpg?itok=kP_frbjO',
#    'publishedAt': '2024-01-11T10:48:17Z',
#    'content': "BENGALURU : Infosys, India's No.2 IT services provider, missed quarterly profit estimates on Thursday, hurt by weak demand from clients amid global economic uncertainty. \r\nConsolidated net profit fel… [+227 chars]"},
#   {'source': {'id': None, 'name': 'Zacjohnson.com'},
#    'author': 'Disclaimer and DMCA',
#    'title': 'K. Dinesh Net Worth – How Much is K. Dinesh Worth?',
#    'description': 'Have you ever wondered how much K. Dinesh, the renowned business entrepreneur, is worth? Well, you’re in the right place! In this article, we will delve into the fascinating world of K. Dinesh and explore his incredible journey to success, his notable achieve…',
#    'url': 'https://zacjohnson.com/k-dinesh-net-worth-2/',
#    'urlToImage': 'https://zacjohnson.com/wp-content/uploads/2024/01/k.-dinesh-net-worth.jpg',
#    'publishedAt': '2024-01-18T11:39:57Z',
#    'content': 'Have you ever wondered how much K. Dinesh, the renowned business entrepreneur, is worth? Well, you’re in the right place! In this article, we will delve into the fascinating world of K. Dinesh and ex… [+39597 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Moneycontrol News',
#    'title': 'Nifty, Sensex move higher on Q3 earnings boost, IT stocks lead gains',
#    'description': 'Market is likely to trade within the current range along with stock-specific actions, says Siddhartha Khemka of Motilal Oswal Financial Services',
#    'url': 'https://www.moneycontrol.com/news/business/markets/nifty-sensex-move-higher-on-q3-earnings-boost-it-stocks-lead-gains-12039151.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2024/01/stocks_market-stock_stock-1-770x433.jpg',
#    'publishedAt': '2024-01-12T04:51:44Z',
#    'content': 'Benchmark indices jumped higher on January 12 morning to inch closer to all-time highs, helped by the buying in information technology stocks following positive results from bigwigs TCS and Infosys.\r… [+2952 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Moneycontrol News',
#    'title': 'Mid-day Mood | Sensex, Nifty inch higher amid positive global cues; IT stocks in focus',
#    'description': 'Analysts anticipate December quarter earning and the US inflation data for December, to be released later in the day, to offer direction to the market',
#    'url': 'https://www.moneycontrol.com/news/business/markets/mid-day-mood-sensex-nifty-inch-higher-amid-positive-global-cues-it-stocks-in-focus-12033281.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2024/01/stocks_sensex_nifty_stockmarket-770x433.jpg',
#    'publishedAt': '2024-01-11T07:06:56Z',
#    'content': 'The equity benchmarks traded higher at noon on January 11 on upbeat\xa0global\xa0cues but the upmove was limited as caution persisted ahead of the release of the US December inflation data due later in the… [+4383 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Sucheta Anchaliya',
#    'title': 'FO Manual| Nifty hits new high; a close above 21,800 can take it to 22,000',
#    'description': 'If the Nifty closes above 21,800 today, which is the weekly expiry, it can hit a new high of 22,000 in a short time, analysts have said',
#    'url': 'https://www.moneycontrol.com/news/business/f-a-close-above-21800-can-take-it-to-22000-12039061.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2023/12/Sensex_up_higher-6-770x433.jpg',
#    'publishedAt': '2024-01-12T07:02:39Z',
#    'content': 'The market traded higher on January 12, with the Nifty hitting a new high helped by gains in IT heavyweights TCS and Infosys following a positive showing in December quarter.\r\nSector wise, the Nifty … [+1843 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Rakesh Patil',
#    'title': 'Market hits fresh record high led by IT stocks; rupee gains',
#    'description': 'In this week, Indian rupee closed higher against the US dollar. The domestic currency gained 24 paise to end at 82.92 in the week ended January 12 against January 5 closing of 83.16.',
#    'url': 'https://www.moneycontrol.com/news/photos/business/markets/market-hits-fresh-record-high-led-by-it-stocks-rupee-gains-12044851.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2024/01/marketup_sensexup-Niftyup-3-770x433.jpg',
# ...
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'BL Bengaluru Bureau',
#    'title': 'Australia’s Regional Investment Corporation subscribes to Infosys Finacle’s SaaS offering',
#    'description': 'Infosys Finacle and Regional Investment Corporation (RIC) collaborate to offer digital lending services to Australian farmers, reducing costs and improving efficiency.',
#    'url': 'https://www.thehindubusinessline.com/info-tech/australias-regional-investment-corporation-subscribes-to-infosys-finacles-saas-offering/article67792585.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/todays-paper/tp-news/yry149/article67732189.ece/alternates/LANDSCAPE_1200/TCS-and-Infosys%2BG99C8SQ21.4.jpg.jpg',
#    'publishedAt': '2024-01-30T12:17:10Z',
#    'content': 'Infosys Finacle, part of EdgeVerve Systems, a wholly-owned subsidiary of Infosys, and Regional Investment Corporation (RIC), an Australian government concessional finance provider for farmers, announ… [+2326 chars]'},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'Reuters',
#    'title': 'Infosys Q3 net profit falls 7.3%, revises full-year revenue forecast amid global uncertainty.',
#    'description': 'Infosys tightens full-year revenue forecast after reporting lower-than-expected quarterly profit due to sluggish client demand.',
#    'url': 'https://www.thehindubusinessline.com/info-tech/infosys-q3-net-profit-falls-73-revises-full-year-revenue-forecast-amid-global-uncertainty/article67730493.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/incoming/9fo6mv/article67730535.ece/alternates/LANDSCAPE_1200/PTI01_11_2024_000209B.jpg',
#    'publishedAt': '2024-01-11T12:49:41Z',
#    'content': "Infosys, India's top IT services provider, tightened its full-year revenue forecast on Thursday after reporting a lower-than-expected quarterly profit estimates on sluggish demand from clients amid g… [+1608 chars]"},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'Haripriya Sureban',
#    'title': 'TCS, Infosys, Wipro workforce shrinks for third consecutive quarter',
#    'description': 'IT majors have flagged that there are no immediate plans to increase employee headcount, rather the focus would be on leveraging the current pool',
#    'url': 'https://www.thehindubusinessline.com/companies/tcs-infosys-wipro-workforce-shrinks-for-third-consecutive-quarter/article67740742.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/todays-paper/tp-news/yry149/article67732189.ece/alternates/LANDSCAPE_1200/TCS-and-Infosys%2BG99C8SQ21.4.jpg.jpg',
#    'publishedAt': '2024-01-14T13:40:34Z',
#    'content': 'The top three Indian IT services firms Tata Consultancy Services (TCS), Infosys and Wipro witnessed a workforce reduction for the third consecutive quarter, with a total decline of 16,254 employees, … [+2128 chars]'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Moneycontrol News',
#    'title': 'Infosys ADR spikes 5% despite weak Q3 performance',
#    'description': 'Consolidated revenue for the quarter came in at Rs 38,821 crore, up 1.3 percent YoY. Revenues for the quarter were marginally above analyst estimates of Rs 38,630 crore.',
#    'url': 'https://www.moneycontrol.com/news/business/stocks/infosys-adr-spikes-5-despite-weak-q3-performance-12036971.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2021/06/infosys-technologies-770x433.jpg',
#    'publishedAt': '2024-01-11T14:58:19Z',
#    'content': 'Infosys ADR (American Depository Receipt) shares jumped\xa0nearly 5 percent even as the company reported a drop in net profit for the quarter ended December 2023.\r\nIndias second-largest IT services comp… [+1307 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Economic Times',
#    'title': 'Infosys Share Price Live Updates: Infosys Closes at Rs 1519.9 with a Volume of 62,472 Shares',
#    'description': "Discover the Infosys Stock Liveblog, your go-to destination for real-time updates and comprehensive analysis of a top-performing stock. Keep track of Infosys's latest details, including: Last traded price 1524.9, Market capitalization: 632539.29, Volume: 6250…",
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/stock-liveblog/infosys-share-price-live-updates-11-jan-2024/liveblog/106713785.cms',
#    'urlToImage': 'https://economictimes.indiatimes.com/thumb/msid-106713785,width-600,resizemode-4,imglength-72191/markets/stocks/stock-liveblog/infosys-share-price-live-updates-11-jan-2024.jpg',
#    'publishedAt': '2024-01-11T03:02:40Z',
#    'content': 'Voltas beko 8 Place Settings Table Top Dishwasher (2020/2021, DT8S, Silver, Inbuilt Heater)\r\nBuy Now'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Economic Times',
#    'title': 'Infosys Share Price Live Updates: Infosys Closes at Rs 1651.45 with 3-Month Return of 20.68%',
#    'description': 'Welcome to the Infosys Stock Liveblog, your ultimate source for real-time updates and analysis of one of the most prominent stocks in the market. Stay on top of the game with our comprehensive coverage, featuring the latest details on Infosys stock, including…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/stock-liveblog/infosys-share-price-live-updates-31-jan-2024/liveblog/107276499.cms',
#    'urlToImage': 'https://economictimes.indiatimes.com/thumb/msid-107276499,width-600,resizemode-4,imglength-72191/markets/stocks/stock-liveblog/infosys-share-price-live-updates-31-jan-2024.jpg',
#    'publishedAt': '2024-01-31T02:59:56Z',
#    'content': 'Voltas beko 8 Place Settings Table Top Dishwasher (2020/2021, DT8S, Silver, Inbuilt Heater)\r\nBuy Now'},
#   {'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'N Mahalakshmi',
#    'title': 'Banking sector will grow but you have to figure out where the sunset of the leadership is: Motilal Oswalâ\x80\x99s Raamdeo Agrawal',
#    'description': 'Concerning competition with China, the good thing is that China has no presence in services, while the services sector constitutes 60 percent of the Indian economy, observed Agrawal.',
#    'url': 'https://www.moneycontrol.com/news/business/markets/banking-sector-will-grow-but-you-have-to-figure-out-where-the-sunset-of-the-leadership-is-motilal-oswals-raamdeo-agrawal-12165901.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2022/03/Raamdeo-Agrawal-770x433.jpg',
#    'publishedAt': '2024-02-01T05:02:17Z',
#    'content': 'The stories for both public sector banks and private banks are different, says Raamdeo Agrawal of Motilal Oswal Financial Services Ltd (MOFSL). According to Agrawal, private sector banks are also fac… [+9927 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Economic Times',
#    'title': 'Infosys Share Price Today Live Updates: Infosys Closes at Rs 1529.3 with 2.28% 3-Month Return',
#    'description': 'Welcome to the Infosys Stock Liveblog, your real-time source for the latest updates and comprehensive analysis on a prominent stock. Dive into the current details of Infosys, including: Last traded price 1524.95, Market capitalization: 634718.24, Volume: 3603…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/stock-liveblog/infosys-share-price-today-live-updates-10-jan-2024/liveblog/106682429.cms',
#    'urlToImage': 'https://economictimes.indiatimes.com/thumb/msid-106682429,width-600,resizemode-4,imglength-72191/markets/stocks/stock-liveblog/infosys-share-price-today-live-updates-10-jan-2024.jpg',
#    'publishedAt': '2024-01-10T03:01:01Z',
#    'content': 'Voltas beko 8 Place Settings Table Top Dishwasher (2020/2021, DT8S, Silver, Inbuilt Heater)\r\nBuy Now'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Economic Times',
#    'title': 'Infosys Share Price Today Live Updates: Infosys Closes at Rs 1631.55 with -0.55% Weekly Return',
#    'description': 'Welcome to the Infosys Stock Liveblog, your real-time source for the latest updates and comprehensive analysis on a prominent stock. Dive into the current details of Infosys, including: Last traded price 1620.25, Market capitalization: 632539.29, Volume: 8066…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/stock-liveblog/infosys-share-price-today-live-updates-17-jan-2024/liveblog/106912792.cms',
#    'urlToImage': 'https://economictimes.indiatimes.com/thumb/msid-106912792,width-600,resizemode-4,imglength-72191/markets/stocks/stock-liveblog/infosys-share-price-today-live-updates-17-jan-2024.jpg',
#    'publishedAt': '2024-01-17T03:03:04Z',
#    'content': 'Voltas beko 8 Place Settings Table Top Dishwasher (2020/2021, DT8S, Silver, Inbuilt Heater)\r\nBuy Now'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Economic Times',
#    'title': 'Infosys Stocks Live Updates: Infosys Closes at Rs 1669.1 with Impressive 3-Month Return of 21.83%',
#    'description': 'Discover the Infosys Stock Liveblog, your ultimate resource for real-time updates and insightful analysis on a prominent stock. Keep track of Infosys with the latest details, including: Last traded price 1665.15, Market capitalization: 692751.2, Volume: 15288…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/stock-liveblog/infosys-stocks-live-updates-29-jan-2024/liveblog/107215139.cms',
#    'urlToImage': 'https://economictimes.indiatimes.com/thumb/msid-107215139,width-600,resizemode-4,imglength-72191/markets/stocks/stock-liveblog/infosys-stocks-live-updates-29-jan-2024.jpg',
#    'publishedAt': '2024-01-29T03:02:25Z',
#    'content': 'Voltas beko 8 Place Settings Table Top Dishwasher (2020/2021, DT8S, Silver, Inbuilt Heater)\r\nBuy Now'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Economic Times',
#    'title': 'Infosys Share Price Today Live Updates: Infosys Closes at Rs 1532.55 with 2.78% 1-Month Return',
#    'description': "Discover the Infosys Stock Liveblog, your go-to destination for real-time updates and comprehensive analysis of a top-performing stock. Keep track of Infosys's latest details, including: Last traded price 1528.95, Market capitalization: 636067.12, Volume: 195…",
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/stock-liveblog/infosys-share-price-today-live-updates-08-jan-2024/liveblog/106622317.cms',
#    'urlToImage': 'https://economictimes.indiatimes.com/thumb/msid-106622317,width-600,resizemode-4,imglength-72191/markets/stocks/stock-liveblog/infosys-share-price-today-live-updates-08-jan-2024.jpg',
#    'publishedAt': '2024-01-08T03:03:07Z',
#    'content': 'Voltas beko 8 Place Settings Table Top Dishwasher (2020/2021, DT8S, Silver, Inbuilt Heater)\r\nBuy Now'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Economic Times',
#    'title': 'Infosys Share Price Today Live Updates: Infosys Closes at Rs 1612.75 with -0.55% Weekly Return',
#    'description': 'Stay up-to-date with the Infosys Stock Liveblog, your comprehensive source for real-time updates and detailed analysis on a prominent stock. Explore the latest information on Infosys, including: Last traded price 1644.95, Market capitalization: 632539.29, Vol…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/stock-liveblog/infosys-share-price-today-live-updates-15-jan-2024/liveblog/106849560.cms',
#    'urlToImage': 'https://economictimes.indiatimes.com/thumb/msid-106849560,width-600,resizemode-4,imglength-72191/markets/stocks/stock-liveblog/infosys-share-price-today-live-updates-15-jan-2024.jpg',
#    'publishedAt': '2024-01-15T03:02:14Z',
#    'content': 'Voltas beko 8 Place Settings Table Top Dishwasher (2020/2021, DT8S, Silver, Inbuilt Heater)\r\nBuy Now'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Economic Times',
#    'title': 'Infosys Share Price Live Updates: Infosys Shares Close at Rs 1657.05 with -0.72% Weekly Return',
#    'description': 'Discover the Infosys Stock Liveblog, your ultimate resource for real-time updates and insightful analysis on a prominent stock. Keep track of Infosys with the latest details, including: Last traded price 1666.05, Market capitalization: 687749.91, Volume: 2748…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/stock-liveblog/infosys-share-price-live-updates-02-feb-2024/liveblog/107340339.cms',
#    'urlToImage': 'https://economictimes.indiatimes.com/thumb/msid-107340339,width-600,resizemode-4,imglength-72191/markets/stocks/stock-liveblog/infosys-share-price-live-updates-02-feb-2024.jpg',
#    'publishedAt': '2024-02-02T03:02:08Z',
#    'content': 'Philips Ac1215/20 Air Purifier, Long Hepa Filter Life Upto 17000 Hours, Removes 99.97% Airborne Pollutants, 4-Stage Filtration with True Hepa Filter(White)\r\nBuy Now'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Economic Times',
#    'title': 'Infosys Share Price Live Updates: Infosys Closes at Rs 1660.9 with 6-Month Beta of 0.3803',
#    'description': 'Stay up-to-date with the Infosys Stock Liveblog, your trusted source for real-time updates and thorough analysis of a prominent stock. Explore the latest details on Infosys, including: Last traded price 1659.55, Market capitalization: 689347.83, Volume: 62180…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/stock-liveblog/infosys-share-price-live-updates-01-feb-2024/liveblog/107308487.cms',
#    'urlToImage': 'https://economictimes.indiatimes.com/thumb/msid-107308487,width-600,resizemode-4,imglength-72191/markets/stocks/stock-liveblog/infosys-share-price-live-updates-01-feb-2024.jpg',
#    'publishedAt': '2024-02-01T03:00:36Z',
#    'content': 'Philips Ac1215/20 Air Purifier, Long Hepa Filter Life Upto 17000 Hours, Removes 99.97% Airborne Pollutants, 4-Stage Filtration with True Hepa Filter(White)\r\nBuy Now'},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'Arushi Mishra',
#    'title': 'Sensex, Nifty open on a positive note; IT sector Q3 results in focus',
#    'description': "Markets open with gains as NSE Nifty & BSE Sensex up; TCS & Infosys Q3 results eyed; FII's long exposure & put-call ratio indicate neutral sentiment.",
#    'url': 'https://www.thehindubusinessline.com/markets/sensex-nifty-open-on-a-positive-note-it-sector-q3-results-in-focus/article67718201.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/incoming/eob45v/article67718300.ece/alternates/LANDSCAPE_1200/image%20%2839%29.jpg',
#    'publishedAt': '2024-01-08T05:06:35Z',
#    'content': 'Markets opened with gains as NSE nifty was up by 0.22 per cent or 47.65 to 21,758.45 points, while the BSE Sensex was at 72,149.33 up by 0.17 per cent or 131.92 points. A total of 3,045 stocks were a… [+1933 chars]'},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'Sudipta  Datta',
#    'title': 'Chitra Banerjee shares experience on her first non-fiction work, ‘An Uncommon Love’ which profiles the power couple, Sudha and Narayana Murthy',
#    'description': 'The book ends with the birth of Infosys – and wanted to tell it because ‘it’s about people who rose from such ordinary backgrounds to become extraordinary people’',
#    'url': 'https://www.thehindubusinessline.com/news/chitra-banerjee-shares-experience-on-her-first-non-fiction-work-an-uncommon-love-which-profiles-the-power-couple-sudha-and-narayana-murthy/article67780173.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/incoming/ptmj28/article67780340.ece/alternates/LANDSCAPE_1200/LIT%20FOR%20LIFE%20FESTIVAL%202024%20LIFE%20TIMES%20OF%20SUDHA%20NARAYANA%20MURTHY_06.jpg',
#    'publishedAt': '2024-01-26T13:52:55Z',
#    'content': 'I can run Infosys, but can he take care of the family? This was the question Sudha Murty pondered over and came up with a no, when Narayana Murthy told her, You run Infosys; I will take care of the f… [+2047 chars]'}]}

# %%
def get_joined_string(newsDict):
    temp_string = []
    for i in range(len(newsDict['articles'])):
        temp = newsDict['articles'][i]
        title = temp['title']
        description = temp['description']
        content = temp['content']
        try:
            final_string = title+description+content
        except ValueError:
            if type(title) == None:
                title = ""
            if type(description) == None:
                description = ""
            if type(content) == None:
                content = ""
            final_string = title+description+content
        except Exception as e:
            print("An error occurred:", e)
        temp_string.append(final_string)
    return temp_string

# %%
def tempo(score_list):
    dict = {
        'negative': -1,
        'neutral': 0,
        'positive': 1
    }
    score = []
    for i in score_list:
        temp = i['label']
        temp = dict[temp]
        score.append(temp)
    total_score = sum(score) 
    return total_score

# %%
tempo(score_list)
# Out:
# 5
